# %% [markdown]
# # Introduction to Qiskit and Connecting to IBM Quantum Computers
#
# ## IBM Quantum Computers: Technical Context
# IBM's quantum computers are based on superconducting qubits. These qubits operate at cryogenic temperatures (close to absolute zero) to achieve superconductivity, where resistance disappears in certain materials.IBM's superconducting quantum computers operate at an ultra-low temperature of approximately 15 millikelvin (mK), which is equivalent to -459.63°F. This temperature is necessary to maintain the superconducting state of qubits by eliminating thermal noise and ensuring quantum coherence. The extreme cooling is achieved using dilution refrigerators, enabling the qubits to perform high-fidelity quantum operations while minimizing decoherence and noise. This technical capability is a cornerstone of IBM's quantum computing technology, allowing for stable quantum states essential for executing quantum algorithms effectively.
#
# Superconducting qubits use Josephson junctions to enable quantum behavior. These junctions allow for the creation and manipulation of quantum states, such as superposition and entanglement.
# IBM's quantum computers employ microwave pulses to control and measure qubits. Error correction and mitigation are critical challenges, and ongoing improvements are made to enhance qubit coherence times, gate fidelity, and overall system performance.

# %% [markdown]
# ## 1. Installing Qiskit & some other things
# I tested my code with Python 3.10.16 - so I know it atleast runs for this version successfully (perhaps it works on previous versions of Python). Use this notebook as a starting point to begin to understand how to make quantum circuits in Qiskit - and execute them with a simulator or real noisy intermediate scale quantum (NISQ) device.

# %%
# !pip install numpy
# !pip install scipy
# !pip install pandas
# !pip install matplotlib
# !pip install qiskit qiskit-ibm-runtime qiskit-ibm-provider seaborn --upgrade
# !pip install pylatexenc
# !pip install qiskit-aer
# Out:
# Requirement already satisfied: numpy in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scipy in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from scipy) (1.26.4)
# Requirement already satisfied: pandas in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: qiskit in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (1.3.1)
# Requirement already satisfied: qiskit-ibm-runtime in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (0.34.0)
# Requirement already satisfied: qiskit-ibm-provider in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: seaborn in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: rustworkx>=0.15.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (0.15.1)
# Requirement already satisfied: numpy<3,>=1.17 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (1.14.1)
# Requirement already satisfied: sympy>=1.3 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (5.4.0)
# Requirement already satisfied: typing-extensions in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit) (0.13.0)
# Requirement already satisfied: requests>=2.19 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-ibm-runtime) (2.32.3)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-ibm-runtime) (2.3.0)
# Requirement already satisfied: websocket-client>=1.5.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-ibm-runtime) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-ibm-runtime) (0.59.0)
# Requirement already satisfied: pydantic<2.10,>=2.5.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-ibm-runtime) (2.9.2)
# Requirement already satisfied: websockets>=10.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-ibm-provider) (14.1)
# Requirement already satisfied: pandas>=1.2 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.22.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from pydantic<2.10,>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from pydantic<2.10,>=2.5.0->qiskit-ibm-runtime) (2.23.4)
# Requirement already satisfied: six>=1.5 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2024.12.14)
# Requirement already satisfied: cryptography>=1.3 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (44.0.0)
# Requirement already satisfied: pyspnego>=0.4.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.11.2)
# Requirement already satisfied: pbr>=2.0.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from sympy>=1.3->qiskit) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.17.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.22.0->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.10.1)
# Requirement already satisfied: pycparser in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.22)
# Requirement already satisfied: pylatexenc in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (2.10)
# Requirement already satisfied: qiskit-aer in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (0.15.1)
# Requirement already satisfied: qiskit>=1.1.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-aer) (1.3.1)
# Requirement already satisfied: numpy>=1.16.3 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-aer) (1.14.1)
# Requirement already satisfied: psutil>=5 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit-aer) (5.9.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.4.0)
# Requirement already satisfied: typing-extensions in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /nfs/gce/projects/MIPDECO/anaconda3/envs/py310/lib/python3.10/site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-aer) (1.3.0)

# %% [markdown]
# ## 2. Getting an IBM Quantum Account
# Follow these steps to get an IBM Quantum account:
# 1. Go to the [IBM Quantum Experience](https://quantum-computing.ibm.com/).
# 2. Sign up for an account (you can use your RIT email for example) or log in if you already have one.
# 3. Navigate to your account settings.
# 4. Copy your IBM Quantum API token.

# %% [markdown]
# ## 3. Setting Up Qiskit to Connect to IBM Quantum
# Save your IBM Quantum API token in a file named 'ibm_quantum_token.txt'.
# The file should contain your token as a single line of text, for example:
# `YOUR_API_TOKEN_HERE`
# This avoids hardcoding the token directly into the notebook.

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# Read the API token from the file.
with open('ibm_quantum_token.txt', 'r') as token_file:
    api_token = token_file.read().strip()

# Save the token to your Qiskit account configuration.

 
QiskitRuntimeService.save_account(channel="ibm_quantum", token=api_token, set_as_default=True, overwrite=True)
 
# Load saved credentials
service = QiskitRuntimeService()
print("Account loaded successfully!")
# Out:
# Account loaded successfully!

# %% [markdown]
# ## Note on Usage Limitations
# IBM Quantum provides free-tier access with monthly limitations on the number of jobs and runtime hours (10 minutes). Ensure to check your account's usage details in the IBM Quantum dashboard to avoid exceeding these limits. I expect for what we want to do during the course we may be close to reaching the monthly rate limit (to be determined).

# %% [markdown]
# ## 4. Testing Connection to IBM Quantum Computers
# This section lists all available backends (quantum computers and simulators) provided by IBM Quantum.
# Ensure that your account is properly connected.

# %%
from qiskit.visualization import plot_gate_map, plot_error_map
import matplotlib.pyplot as plt

backends = service.backends()

print("Available backends:")
for backend in backends:
    # Print the name of each backend.
    print(backend)
    print((backend.name, backend.configuration().simulator, backend.status().operational))
# Out:
# Available backends:
# <IBMBackend('ibm_brisbane')>
# ('ibm_brisbane', False, True)
# <IBMBackend('ibm_kyiv')>
# ('ibm_kyiv', False, True)
# <IBMBackend('ibm_sherbrooke')>
# ('ibm_sherbrooke', False, True)

# %% [markdown]
# ## 5. Running a Simple Quantum Circuit
# This section demonstrates creating and running a simple quantum circuit.

# %%
from qiskit import QuantumCircuit
from qiskit_ibm_runtime import QiskitRuntimeService, Session, Sampler
from qiskit.visualization import plot_histogram

# Step 1: Create a simple quantum circuit with one qubit and one classical bit.
qc = QuantumCircuit(1, 1)  # Initialize a quantum circuit with 1 qubit and 1 classical bit.
qc.h(0)  # Apply a Hadamard gate to the qubit (creates a superposition state).
qc.measure(0, 0)  # Measure the state of the qubit and store the result in the classical bit.

# Visualize the circuit to understand its structure.
print("Quantum Circuit:")
print(qc)
qc.draw('mpl')  # Use matplotlib to render the circuit diagram.
# Out:
# Quantum Circuit:
#      ┌───┐┌─┐
#   q: ┤ H ├┤M├
#      └───┘└╥┘
# c: 1/══════╩═
#            0

# %% [markdown]
# ## 6. Choosing a Backend and Running the Circuit
# This step involves selecting a backend and running the quantum circuit.

# %%
import networkx as nx

import seaborn as sns
from qiskit_ibm_provider import IBMProvider
# %matplotlib inline

# Step 2: Choose a backend to execute the circuit. Find the least busy backend with operational status and real quantum hardware
service = QiskitRuntimeService()
# Get a backend that is a real quantum device, and not a simulator
backend = service.least_busy(operational=True, simulator=False)
print(f"Least busy backend: {backend.name}")



print(f"Running on backend: {backend.name}")




# Extract backend properties (T1, T2, etc.)
backend_config = backend.configuration()
backend_properties = backend.properties()

# Collect qubit error rates

print("Backend Parameters:")
print(f"Qubit count: {backend_config.n_qubits}")
# T1 is the relaxation time, which measures how quickly a qubit loses its state due to interaction with the environment.
# Value Proposition of High T1:
# A higher T1 allows for longer quantum operations and reduces the likelihood of errors due to energy relaxation.
# This is especially valuable for deep quantum circuits or algorithms that require extended computation times.
# Challenges: Achieving high T1 is difficult due to environmental noise, energy dissipation, and material limitations in superconducting qubits.
print("T1 times (in microseconds):")
for i, qubit in enumerate(backend_properties.qubits):
    t1 = qubit[0].value  # T1 is the first property of each qubit.
    print(f"Qubit {i}: {t1:.1f} µs")

# T2 is the dephasing time, which measures how quickly a qubit loses coherence due to phase errors.
# Value Proposition of High T2:
# A higher T2 ensures that quantum states remain coherent for longer durations, enabling more accurate computations and reducing errors in quantum algorithms.
# This is critical for operations involving entanglement or interference patterns.
# Challenges: Achieving high T2 requires minimizing phase noise, which is influenced by material quality and external fluctuations.
print("T2 times (in microseconds):")
for i, qubit in enumerate(backend_properties.qubits):
    t2 = qubit[1].value  # T2 is the second property of each qubit.
    print(f"Qubit {i}: {t2:.1f} µs")

# T2* (T2 star) is an observed coherence time that includes inhomogeneous broadening effects.
# Value Proposition of High T2*:
# A high T2* value implies minimal inhomogeneous noise and better overall coherence in practical scenarios.
# This is important for algorithms sensitive to noise or for achieving high-fidelity gate operations.
# Challenges: T2* is generally lower than T2 due to environmental and fabrication imperfections, which are hard to eliminate completely.
print("T2* times (if available):")
for i, qubit in enumerate(backend_properties.qubits):
    t2_star = next((p.value for p in qubit if p.name == "T2*"), None)
    if t2_star:
        print(f"Qubit {i}: {t2_star:.1f} µs (T2 star)")
    else:
        print(f"Qubit {i}: T2* not available")

# Relationship between T1 and T2:
# T2 is always less than or equal to 2*T1. This relationship arises because T2 includes the effects of T1 (energy relaxation)
# as well as additional dephasing mechanisms. T2* is generally less than T2 due to inhomogeneous broadening effects.
print("Relationship between T1, T2, and T2*: T2 <= 2*T1 and T2* <= T2")

# Exhaustive demonstration of all qubit parameters:
print("Exhaustive qubit parameters:")
for i, qubit in enumerate(backend_properties.qubits):
    print(f"Qubit {i} parameters:")
    for param in qubit:
        print(f" - {param.name}: {param.value} {param.unit}")
        # Add a description of each parameter's importance:
        if param.name == "T1":
            print("   (T1: Relaxation time, defines qubit longevity)")
        elif param.name == "T2":
            print("   (T2: Dephasing time, defines qubit coherence)")
        elif param.name == "T2*":
            print("   (T2*: Observed coherence time, includes inhomogeneous effects)")
        elif param.name == "frequency":
            print("   (Frequency: Resonance frequency of the qubit, important for addressing and control)")
        elif param.name == "anharmonicity":
            print("   (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)")
        else:
            print("   (Other parameter)")
# Out:
# Least busy backend: ibm_kyiv
# Running on backend: ibm_kyiv
# Backend Parameters:
# Qubit count: 127
# T1 times (in microseconds):
# Qubit 0: 366.3 µs
# Qubit 1: 429.9 µs
# Qubit 2: 244.9 µs
# Qubit 3: 353.3 µs
# Qubit 4: 188.3 µs
# Qubit 5: 273.1 µs
# Qubit 6: 334.4 µs
# Qubit 7: 430.0 µs
# Qubit 8: 307.6 µs
# Qubit 9: 447.8 µs
# Qubit 10: 311.5 µs
# Qubit 11: 351.5 µs
# Qubit 12: 422.7 µs
# Qubit 13: 215.8 µs
# Qubit 14: 354.7 µs
# Qubit 15: 274.6 µs
# Qubit 16: 368.8 µs
# Qubit 17: 196.4 µs
# Qubit 18: 288.6 µs
# Qubit 19: 298.4 µs
# Qubit 20: 436.8 µs
# Qubit 21: 384.9 µs
# Qubit 22: 373.3 µs
# Qubit 23: 55.7 µs
# Qubit 24: 277.7 µs
# Qubit 25: 275.4 µs
# Qubit 26: 130.5 µs
# Qubit 27: 328.0 µs
# Qubit 28: 146.9 µs
# Qubit 29: 217.3 µs
# Qubit 30: 266.5 µs
# Qubit 31: 267.3 µs
# Qubit 32: 313.5 µs
# Qubit 33: 435.3 µs
# Qubit 34: 355.5 µs
# Qubit 35: 370.4 µs
# Qubit 36: 472.5 µs
# Qubit 37: 435.7 µs
# Qubit 38: 452.3 µs
# Qubit 39: 416.6 µs
# Qubit 40: 377.2 µs
# Qubit 41: 160.7 µs
# Qubit 42: 245.5 µs
# Qubit 43: 134.0 µs
# Qubit 44: 15.4 µs
# Qubit 45: 295.4 µs
# Qubit 46: 268.1 µs
# Qubit 47: 306.8 µs
# Qubit 48: 230.0 µs
# Qubit 49: 242.3 µs
# Qubit 50: 373.7 µs
# Qubit 51: 267.8 µs
# Qubit 52: 346.4 µs
# Qubit 53: 332.1 µs
# Qubit 54: 364.6 µs
# Qubit 55: 397.6 µs
# Qubit 56: 312.6 µs
# Qubit 57: 167.7 µs
# Qubit 58: 270.1 µs
# Qubit 59: 323.4 µs
# Qubit 60: 405.7 µs
# Qubit 61: 278.8 µs
# Qubit 62: 236.6 µs
# Qubit 63: 308.3 µs
# Qubit 64: 214.1 µs
# Qubit 65: 285.4 µs
# Qubit 66: 181.1 µs
# Qubit 67: 291.3 µs
# Qubit 68: 243.8 µs
# Qubit 69: 181.8 µs
# Qubit 70: 262.4 µs
# Qubit 71: 260.7 µs
# Qubit 72: 271.5 µs
# Qubit 73: 229.0 µs
# Qubit 74: 288.6 µs
# Qubit 75: 281.1 µs
# Qubit 76: 277.4 µs
# Qubit 77: 258.4 µs
# Qubit 78: 11.0 µs
# Qubit 79: 241.4 µs
# Qubit 80: 17.0 µs
# Qubit 81: 212.3 µs
# Qubit 82: 220.8 µs
# Qubit 83: 383.6 µs
# Qubit 84: 266.6 µs
# Qubit 85: 266.4 µs
# Qubit 86: 56.7 µs
# Qubit 87: 203.4 µs
# Qubit 88: 223.5 µs
# Qubit 89: 230.1 µs
# Qubit 90: 306.3 µs
# Qubit 91: 276.9 µs
# Qubit 92: 17.2 µs
# Qubit 93: 173.4 µs
# Qubit 94: 203.1 µs
# Qubit 95: 219.1 µs
# Qubit 96: 280.5 µs
# Qubit 97: 243.3 µs
# Qubit 98: 61.9 µs
# Qubit 99: 176.7 µs
# Qubit 100: 300.4 µs
# Qubit 101: 274.4 µs
# Qubit 102: 186.1 µs
# Qubit 103: 229.4 µs
# Qubit 104: 274.3 µs
# Qubit 105: 273.4 µs
# Qubit 106: 307.3 µs
# Qubit 107: 220.2 µs
# Qubit 108: 394.4 µs
# Qubit 109: 205.8 µs
# Qubit 110: 246.6 µs
# Qubit 111: 178.1 µs
# Qubit 112: 372.0 µs
# Qubit 113: 268.9 µs
# Qubit 114: 202.9 µs
# Qubit 115: 302.0 µs
# Qubit 116: 61.3 µs
# Qubit 117: 230.8 µs
# Qubit 118: 147.3 µs
# Qubit 119: 277.3 µs
# Qubit 120: 239.7 µs
# Qubit 121: 323.8 µs
# Qubit 122: 107.1 µs
# Qubit 123: 252.7 µs
# Qubit 124: 163.4 µs
# Qubit 125: 240.2 µs
# Qubit 126: 304.3 µs
# T2 times (in microseconds):
# Qubit 0: 355.7 µs
# Qubit 1: 191.7 µs
# Qubit 2: 110.5 µs
# Qubit 3: 154.4 µs
# Qubit 4: 127.8 µs
# Qubit 5: 261.3 µs
# Qubit 6: 168.8 µs
# Qubit 7: 557.9 µs
# Qubit 8: 260.0 µs
# Qubit 9: 341.8 µs
# Qubit 10: 72.8 µs
# Qubit 11: 326.0 µs
# Qubit 12: 350.9 µs
# Qubit 13: 71.6 µs
# Qubit 14: 375.8 µs
# Qubit 15: 63.7 µs
# Qubit 16: 127.5 µs
# Qubit 17: 53.0 µs
# Qubit 18: 44.4 µs
# Qubit 19: 171.9 µs
# Qubit 20: 423.3 µs
# Qubit 21: 54.5 µs
# Qubit 22: 177.6 µs
# Qubit 23: 54.1 µs
# Qubit 24: 67.0 µs
# Qubit 25: 315.5 µs
# Qubit 26: 89.7 µs
# Qubit 27: 86.4 µs
# Qubit 28: 12.6 µs
# Qubit 29: 200.2 µs
# Qubit 30: 105.9 µs
# Qubit 31: 164.2 µs
# Qubit 32: 109.6 µs
# Qubit 33: 216.1 µs
# Qubit 34: 141.8 µs
# Qubit 35: 101.1 µs
# Qubit 36: 27.7 µs
# Qubit 37: 232.9 µs
# Qubit 38: 318.8 µs
# Qubit 39: 63.5 µs
# Qubit 40: 33.0 µs
# Qubit 41: 251.5 µs
# Qubit 42: 73.9 µs
# Qubit 43: 159.3 µs
# Qubit 44: 19.3 µs
# Qubit 45: 118.4 µs
# Qubit 46: 51.2 µs
# Qubit 47: 121.1 µs
# Qubit 48: 68.9 µs
# Qubit 49: 82.1 µs
# Qubit 50: 102.8 µs
# Qubit 51: 72.9 µs
# Qubit 52: 36.0 µs
# Qubit 53: 430.2 µs
# Qubit 54: 19.7 µs
# Qubit 55: 44.2 µs
# Qubit 56: 311.6 µs
# Qubit 57: 28.9 µs
# Qubit 58: 39.5 µs
# Qubit 59: 83.1 µs
# Qubit 60: 475.3 µs
# Qubit 61: 138.2 µs
# Qubit 62: 26.0 µs
# Qubit 63: 170.6 µs
# Qubit 64: 38.4 µs
# Qubit 65: 343.4 µs
# Qubit 66: 63.1 µs
# Qubit 67: 89.0 µs
# Qubit 68: 85.6 µs
# Qubit 69: 68.2 µs
# Qubit 70: 66.6 µs
# Qubit 71: 45.5 µs
# Qubit 72: 296.8 µs
# Qubit 73: 124.1 µs
# Qubit 74: 277.7 µs
# Qubit 75: 182.1 µs
# Qubit 76: 280.9 µs
# Qubit 77: 264.1 µs
# Qubit 78: 18.7 µs
# Qubit 79: 72.2 µs
# Qubit 80: 21.0 µs
# Qubit 81: 73.8 µs
# Qubit 82: 93.2 µs
# Qubit 83: 79.6 µs
# Qubit 84: 206.7 µs
# Qubit 85: 243.5 µs
# Qubit 86: 36.6 µs
# Qubit 87: 57.9 µs
# Qubit 88: 37.0 µs
# Qubit 89: 215.8 µs
# Qubit 90: 240.7 µs
# Qubit 91: 78.5 µs
# Qubit 92: 26.8 µs
# Qubit 93: 126.3 µs
# Qubit 94: 193.9 µs
# Qubit 95: 18.2 µs
# Qubit 96: 232.0 µs
# Qubit 97: 259.3 µs
# Qubit 98: 24.0 µs
# Qubit 99: 86.8 µs
# Qubit 100: 69.2 µs
# Qubit 101: 304.4 µs
# Qubit 102: 226.9 µs
# Qubit 103: 144.3 µs
# Qubit 104: 32.4 µs
# Qubit 105: 90.3 µs
# Qubit 106: 45.7 µs
# Qubit 107: 41.6 µs
# Qubit 108: 346.9 µs
# Qubit 109: 13.5 µs
# Qubit 110: 60.8 µs
# Qubit 111: 114.6 µs
# Qubit 112: 382.8 µs
# Qubit 113: 109.4 µs
# Qubit 114: 15.9 µs
# Qubit 115: 245.8 µs
# Qubit 116: 74.4 µs
# Qubit 117: 63.4 µs
# Qubit 118: 217.5 µs
# Qubit 119: 253.3 µs
# Qubit 120: 417.9 µs
# Qubit 121: 102.2 µs
# Qubit 122: 86.7 µs
# Qubit 123: 274.9 µs
# Qubit 124: 47.8 µs
# Qubit 125: 300.4 µs
# Qubit 126: 74.2 µs
# T2* times (if available):
# Qubit 0: T2* not available
# Qubit 1: T2* not available
# Qubit 2: T2* not available
# Qubit 3: T2* not available
# Qubit 4: T2* not available
# Qubit 5: T2* not available
# Qubit 6: T2* not available
# Qubit 7: T2* not available
# Qubit 8: T2* not available
# Qubit 9: T2* not available
# Qubit 10: T2* not available
# Qubit 11: T2* not available
# Qubit 12: T2* not available
# Qubit 13: T2* not available
# Qubit 14: T2* not available
# Qubit 15: T2* not available
# Qubit 16: T2* not available
# Qubit 17: T2* not available
# Qubit 18: T2* not available
# Qubit 19: T2* not available
# Qubit 20: T2* not available
# Qubit 21: T2* not available
# Qubit 22: T2* not available
# Qubit 23: T2* not available
# Qubit 24: T2* not available
# Qubit 25: T2* not available
# Qubit 26: T2* not available
# Qubit 27: T2* not available
# Qubit 28: T2* not available
# Qubit 29: T2* not available
# Qubit 30: T2* not available
# Qubit 31: T2* not available
# Qubit 32: T2* not available
# Qubit 33: T2* not available
# Qubit 34: T2* not available
# Qubit 35: T2* not available
# Qubit 36: T2* not available
# Qubit 37: T2* not available
# Qubit 38: T2* not available
# Qubit 39: T2* not available
# Qubit 40: T2* not available
# Qubit 41: T2* not available
# Qubit 42: T2* not available
# Qubit 43: T2* not available
# Qubit 44: T2* not available
# Qubit 45: T2* not available
# Qubit 46: T2* not available
# Qubit 47: T2* not available
# Qubit 48: T2* not available
# Qubit 49: T2* not available
# Qubit 50: T2* not available
# Qubit 51: T2* not available
# Qubit 52: T2* not available
# Qubit 53: T2* not available
# Qubit 54: T2* not available
# Qubit 55: T2* not available
# Qubit 56: T2* not available
# Qubit 57: T2* not available
# Qubit 58: T2* not available
# Qubit 59: T2* not available
# Qubit 60: T2* not available
# Qubit 61: T2* not available
# Qubit 62: T2* not available
# Qubit 63: T2* not available
# Qubit 64: T2* not available
# Qubit 65: T2* not available
# Qubit 66: T2* not available
# Qubit 67: T2* not available
# Qubit 68: T2* not available
# Qubit 69: T2* not available
# Qubit 70: T2* not available
# Qubit 71: T2* not available
# Qubit 72: T2* not available
# Qubit 73: T2* not available
# Qubit 74: T2* not available
# Qubit 75: T2* not available
# Qubit 76: T2* not available
# Qubit 77: T2* not available
# Qubit 78: T2* not available
# Qubit 79: T2* not available
# Qubit 80: T2* not available
# Qubit 81: T2* not available
# Qubit 82: T2* not available
# Qubit 83: T2* not available
# Qubit 84: T2* not available
# Qubit 85: T2* not available
# Qubit 86: T2* not available
# Qubit 87: T2* not available
# Qubit 88: T2* not available
# Qubit 89: T2* not available
# Qubit 90: T2* not available
# Qubit 91: T2* not available
# Qubit 92: T2* not available
# Qubit 93: T2* not available
# Qubit 94: T2* not available
# Qubit 95: T2* not available
# Qubit 96: T2* not available
# Qubit 97: T2* not available
# Qubit 98: T2* not available
# Qubit 99: T2* not available
# Qubit 100: T2* not available
# Qubit 101: T2* not available
# Qubit 102: T2* not available
# Qubit 103: T2* not available
# Qubit 104: T2* not available
# Qubit 105: T2* not available
# Qubit 106: T2* not available
# Qubit 107: T2* not available
# Qubit 108: T2* not available
# Qubit 109: T2* not available
# Qubit 110: T2* not available
# Qubit 111: T2* not available
# Qubit 112: T2* not available
# Qubit 113: T2* not available
# Qubit 114: T2* not available
# Qubit 115: T2* not available
# Qubit 116: T2* not available
# Qubit 117: T2* not available
# Qubit 118: T2* not available
# Qubit 119: T2* not available
# Qubit 120: T2* not available
# Qubit 121: T2* not available
# Qubit 122: T2* not available
# Qubit 123: T2* not available
# Qubit 124: T2* not available
# Qubit 125: T2* not available
# Qubit 126: T2* not available
# Relationship between T1, T2, and T2*: T2 <= 2*T1 and T2* <= T2
# Exhaustive qubit parameters:
# Qubit 0 parameters:
#  - T1: 366.3498868738296 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 355.6878648503664 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.655635941260403 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3110632460863657 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0017000000000000348
#    (Other parameter)
#  - prob_meas0_prep1: 0.0023999999999999577
#    (Other parameter)
#  - prob_meas1_prep0: 0.001
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 1 parameters:
#  - T1: 429.92584206138093 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 191.66594191066613 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.534961840941134 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31302980539784336 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0038000000000000256
#    (Other parameter)
#  - prob_meas0_prep1: 0.0031999999999999806
#    (Other parameter)
#  - prob_meas1_prep0: 0.0044
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 2 parameters:
#  - T1: 244.8987721108304 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 110.51724695397553 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.680131153988957 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3092563684570482 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0050000000000000044
#    (Other parameter)
#  - prob_meas0_prep1: 0.006399999999999961
#    (Other parameter)
#  - prob_meas1_prep0: 0.0036
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 3 parameters:
#  - T1: 353.2554463261734 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 154.36130208355166 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.606648839023887 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.25135835423971303 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0049000000000000155
#    (Other parameter)
#  - prob_meas0_prep1: 0.0042
#    (Other parameter)
#  - prob_meas1_prep0: 0.005600000000000049
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 4 parameters:
#  - T1: 188.31993387806676 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 127.83882730016128 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.462332053535673 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.25507850560311957 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.06489999999999996
#    (Other parameter)
#  - prob_meas0_prep1: 0.06440000000000001
#    (Other parameter)
#  - prob_meas1_prep0: 0.0654
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 5 parameters:
#  - T1: 273.1068204331515 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 261.3433830297242 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.426691023393138 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.2804432142711162 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.012699999999999934
#    (Other parameter)
#  - prob_meas0_prep1: 0.0156
#    (Other parameter)
#  - prob_meas1_prep0: 0.009800000000000031
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 6 parameters:
#  - T1: 334.40181764834256 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 168.79473204576107 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.640083075198973 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3108103399516748 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0045999999999999375
#    (Other parameter)
#  - prob_meas0_prep1: 0.0050000000000000044
#    (Other parameter)
#  - prob_meas1_prep0: 0.0042
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 7 parameters:
#  - T1: 429.9788495287484 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 557.8595943118245 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.4756953635913295 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.2813271220492828 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0031999999999999806
#    (Other parameter)
#  - prob_meas0_prep1: 0.0032
#    (Other parameter)
#  - prob_meas1_prep0: 0.0031999999999999806
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 8 parameters:
#  - T1: 307.5824262356286 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 260.0398837331655 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.401807177765293 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.25507427876459826 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.03849999999999998
#    (Other parameter)
#  - prob_meas0_prep1: 0.031399999999999983
#    (Other parameter)
#  - prob_meas1_prep0: 0.0456
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 9 parameters:
#  - T1: 447.8169347879239 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 341.8188840399342 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.519003106376951 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.29730654926594685 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.009200000000000097
#    (Other parameter)
#  - prob_meas0_prep1: 0.009600000000000053
#    (Other parameter)
#  - prob_meas1_prep0: 0.0088
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 10 parameters:
#  - T1: 311.52709577534705 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 72.78469035675914 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.628366495276091 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.006099999999999994
#    (Other parameter)
#  - prob_meas0_prep1: 0.0074
#    (Other parameter)
#  - prob_meas1_prep0: 0.0048000000000000265
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 11 parameters:
#  - T1: 351.5223943980508 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 326.0271141791839 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.5715191878972865 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31187801080194943 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.012199999999999989
#    (Other parameter)
#  - prob_meas0_prep1: 0.0144
#    (Other parameter)
#  - prob_meas1_prep0: 0.010000000000000009
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 12 parameters:
#  - T1: 422.65690418516124 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 350.9462575897206 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.4643268393260955 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3114335997689411 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.01539999999999997
#    (Other parameter)
#  - prob_meas0_prep1: 0.0172
#    (Other parameter)
#  - prob_meas1_prep0: 0.013599999999999945
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 13 parameters:
#  - T1: 215.84284572456505 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 71.57027450628522 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.573361711413551 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.012700000000000045
#    (Other parameter)
#  - prob_meas0_prep1: 0.014800000000000035
#    (Other parameter)
#  - prob_meas1_prep0: 0.0106
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 14 parameters:
#  - T1: 354.67254026645764 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 375.7653572620709 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.6039886202276605 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3075149117337717 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0041999999999999815
#    (Other parameter)
#  - prob_meas0_prep1: 0.0050000000000000044
#    (Other parameter)
#  - prob_meas1_prep0: 0.0034
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 15 parameters:
#  - T1: 274.563539094621 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 63.66625790844479 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.495993229027731 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3235838974181829 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.017299999999999982
#    (Other parameter)
#  - prob_meas0_prep1: 0.018000000000000016
#    (Other parameter)
#  - prob_meas1_prep0: 0.0166
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 16 parameters:
#  - T1: 368.84093436139904 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 127.52809934598801 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.513220078588561 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31250997509736017 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.010800000000000032
#    (Other parameter)
#  - prob_meas0_prep1: 0.011800000000000033
#    (Other parameter)
#  - prob_meas1_prep0: 0.0098
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 17 parameters:
#  - T1: 196.3507488998592 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 52.99707563540231 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.675810947964961 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3222371456169295 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.06740000000000002
#    (Other parameter)
#  - prob_meas0_prep1: 0.0728
#    (Other parameter)
#  - prob_meas1_prep0: 0.062000000000000055
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 18 parameters:
#  - T1: 288.61380257730593 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 44.35493769533376 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.514796367923294 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.32147907217387134 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0042999999999999705
#    (Other parameter)
#  - prob_meas0_prep1: 0.0058
#    (Other parameter)
#  - prob_meas1_prep0: 0.0028000000000000247
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 19 parameters:
#  - T1: 298.44772269308226 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 171.86375969911217 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.444137772324761 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3142519677447134 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.023600000000000065
#    (Other parameter)
#  - prob_meas0_prep1: 0.023800000000000043
#    (Other parameter)
#  - prob_meas1_prep0: 0.0234
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 20 parameters:
#  - T1: 436.7745245704512 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 423.28580117089666 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.341293562430945 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31659680563840864 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.042300000000000004
#    (Other parameter)
#  - prob_meas0_prep1: 0.054200000000000026
#    (Other parameter)
#  - prob_meas1_prep0: 0.0304
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 21 parameters:
#  - T1: 384.9419302870174 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 54.47660317633223 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.485184049594363 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3137510643214938 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.01529999999999998
#    (Other parameter)
#  - prob_meas0_prep1: 0.0156
#    (Other parameter)
#  - prob_meas1_prep0: 0.015000000000000013
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 22 parameters:
#  - T1: 373.2648548427894 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 177.6244881016651 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.382949700531839 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3235699465364606 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.010099999999999998
#    (Other parameter)
#  - prob_meas0_prep1: 0.0098
#    (Other parameter)
#  - prob_meas1_prep0: 0.010399999999999965
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 23 parameters:
#  - T1: 55.74619651144401 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 54.102590306436625 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.5317548512468 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.34910557092715694 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.02410000000000001
#    (Other parameter)
#  - prob_meas0_prep1: 0.02859999999999996
#    (Other parameter)
#  - prob_meas1_prep0: 0.0196
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 24 parameters:
#  - T1: 277.6557053974455 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 66.96225615389301 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.646168460208934 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3098937587669715 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.007800000000000029
#    (Other parameter)
#  - prob_meas0_prep1: 0.009800000000000031
#    (Other parameter)
#  - prob_meas1_prep0: 0.0058
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 25 parameters:
#  - T1: 275.3828682284211 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 315.5068163850943 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.702190205129314 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3104687819443247 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.00990000000000002
#    (Other parameter)
#  - prob_meas0_prep1: 0.011399999999999966
#    (Other parameter)
#  - prob_meas1_prep0: 0.0084
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 26 parameters:
#  - T1: 130.4563543696564 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 89.66791482043917 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.648806384183855 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.024399999999999977
#    (Other parameter)
#  - prob_meas0_prep1: 0.04279999999999995
#    (Other parameter)
#  - prob_meas1_prep0: 0.006
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 27 parameters:
#  - T1: 328.02175328464244 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 86.35222999716738 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.609915970719704 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.2878947957747321 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0706
#    (Other parameter)
#  - prob_meas0_prep1: 0.0434
#    (Other parameter)
#  - prob_meas1_prep0: 0.0978
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 28 parameters:
#  - T1: 146.88601972687033 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 12.64612760552247 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.516877720704997 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31512500613226163 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.008299999999999974
#    (Other parameter)
#  - prob_meas0_prep1: 0.011800000000000033
#    (Other parameter)
#  - prob_meas1_prep0: 0.0048
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 29 parameters:
#  - T1: 217.30942610848027 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 200.17310332084023 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.460012888638609 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3164470706353105 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.016199999999999992
#    (Other parameter)
#  - prob_meas0_prep1: 0.0178
#    (Other parameter)
#  - prob_meas1_prep0: 0.014599999999999946
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 30 parameters:
#  - T1: 266.53398044703243 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 105.92958761590323 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.646421356031527 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.2835614267270895 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.06630000000000003
#    (Other parameter)
#  - prob_meas0_prep1: 0.0686
#    (Other parameter)
#  - prob_meas1_prep0: 0.064
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 31 parameters:
#  - T1: 267.33073454169244 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 164.20224461497412 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.612989770069271 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3112675880038357 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.013600000000000056
#    (Other parameter)
#  - prob_meas0_prep1: 0.0166
#    (Other parameter)
#  - prob_meas1_prep0: 0.010600000000000054
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 32 parameters:
#  - T1: 313.4820932914314 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 109.55692968843488 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.4992793557574196 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3128171150093984 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.014000000000000012
#    (Other parameter)
#  - prob_meas0_prep1: 0.0144
#    (Other parameter)
#  - prob_meas1_prep0: 0.013599999999999945
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 33 parameters:
#  - T1: 435.3422401909385 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 216.06383641817186 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.596930427092562 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.006299999999999972
#    (Other parameter)
#  - prob_meas0_prep1: 0.009800000000000031
#    (Other parameter)
#  - prob_meas1_prep0: 0.0028
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 34 parameters:
#  - T1: 355.5125006960105 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 141.84983586100176 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.561973444800647 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.022199999999999998
#    (Other parameter)
#  - prob_meas0_prep1: 0.03539999999999999
#    (Other parameter)
#  - prob_meas1_prep0: 0.009
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 35 parameters:
#  - T1: 370.35730349616 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 101.11090414952174 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.721869468739795 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.30795810239191124 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.00550000000000006
#    (Other parameter)
#  - prob_meas0_prep1: 0.00880000000000003
#    (Other parameter)
#  - prob_meas1_prep0: 0.0022
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 36 parameters:
#  - T1: 472.53121626296013 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 27.72646062527648 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.608033736126435 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31164624269239977 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.010099999999999998
#    (Other parameter)
#  - prob_meas0_prep1: 0.017000000000000015
#    (Other parameter)
#  - prob_meas1_prep0: 0.0032
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 37 parameters:
#  - T1: 435.7243790311908 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 232.87287774940438 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.497763589462752 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.016000000000000014
#    (Other parameter)
#  - prob_meas0_prep1: 0.0138
#    (Other parameter)
#  - prob_meas1_prep0: 0.018199999999999994
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 38 parameters:
#  - T1: 452.2865297726866 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 318.76259235740935 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.475497200239481 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.33539586706236296 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.011399999999999966
#    (Other parameter)
#  - prob_meas0_prep1: 0.013599999999999945
#    (Other parameter)
#  - prob_meas1_prep0: 0.0092
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 39 parameters:
#  - T1: 416.5998704622704 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 63.48863604238519 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.50442719241777 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31295465019890567 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.007099999999999995
#    (Other parameter)
#  - prob_meas0_prep1: 0.008199999999999985
#    (Other parameter)
#  - prob_meas1_prep0: 0.006
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 40 parameters:
#  - T1: 377.17699338972255 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 32.99199938023131 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.464340770109418 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.33809284738007156 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.006800000000000028
#    (Other parameter)
#  - prob_meas0_prep1: 0.0088
#    (Other parameter)
#  - prob_meas1_prep0: 0.0048000000000000265
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 41 parameters:
#  - T1: 160.7442912353955 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 251.53990842684263 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.575902087160036 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3452224783858925 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0041999999999999815
#    (Other parameter)
#  - prob_meas0_prep1: 0.00539999999999996
#    (Other parameter)
#  - prob_meas1_prep0: 0.003
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 42 parameters:
#  - T1: 245.47456963459834 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 73.90513269347171 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.641383321677253 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.33193206992602775 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0044999999999999485
#    (Other parameter)
#  - prob_meas0_prep1: 0.008199999999999985
#    (Other parameter)
#  - prob_meas1_prep0: 0.0008
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 43 parameters:
#  - T1: 134.0287173699313 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 159.33064741727375 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.523110680370109 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3218076034687584 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0045999999999999375
#    (Other parameter)
#  - prob_meas0_prep1: 0.007800000000000029
#    (Other parameter)
#  - prob_meas1_prep0: 0.0014
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 44 parameters:
#  - T1: 15.425145486419655 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 19.291775313257254 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.594478589072467 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.2725547830259511 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.07050000000000001
#    (Other parameter)
#  - prob_meas0_prep1: 0.08720000000000006
#    (Other parameter)
#  - prob_meas1_prep0: 0.0538
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 45 parameters:
#  - T1: 295.3528017476744 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 118.37155229840228 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.6304387648243335 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31121477664524183 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0018000000000000238
#    (Other parameter)
#  - prob_meas0_prep1: 0.0026000000000000467
#    (Other parameter)
#  - prob_meas1_prep0: 0.001
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 46 parameters:
#  - T1: 268.0737923635981 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 51.1727493006787 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.710109661513949 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31051099269051724 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.011800000000000033
#    (Other parameter)
#  - prob_meas0_prep1: 0.018199999999999994
#    (Other parameter)
#  - prob_meas1_prep0: 0.0054
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 47 parameters:
#  - T1: 306.80548901911953 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 121.05782535732581 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.680581662076691 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.2791698234955903 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.09960000000000002
#    (Other parameter)
#  - prob_meas0_prep1: 0.04520000000000002
#    (Other parameter)
#  - prob_meas1_prep0: 0.154
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 48 parameters:
#  - T1: 230.04810855678303 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 68.8611722067496 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.625124339380575 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31121814662509445 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0032999999999999696
#    (Other parameter)
#  - prob_meas0_prep1: 0.00539999999999996
#    (Other parameter)
#  - prob_meas1_prep0: 0.0012
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 49 parameters:
#  - T1: 242.3475191582381 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 82.12980545488467 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.581943342811297 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.35202725215057706 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0121
#    (Other parameter)
#  - prob_meas0_prep1: 0.012599999999999945
#    (Other parameter)
#  - prob_meas1_prep0: 0.0116
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 50 parameters:
#  - T1: 373.744175134871 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 102.77607972660581 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.457760986944842 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3137510834931671 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.006199999999999983
#    (Other parameter)
#  - prob_meas0_prep1: 0.006
#    (Other parameter)
#  - prob_meas1_prep0: 0.006399999999999961
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 51 parameters:
#  - T1: 267.80629890449535 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 72.94305506484326 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.565293940503579 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.2968087163341602 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.05930000000000002
#    (Other parameter)
#  - prob_meas0_prep1: 0.06159999999999999
#    (Other parameter)
#  - prob_meas1_prep0: 0.057
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 52 parameters:
#  - T1: 346.37109109351934 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 36.021972322600355 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.444418931009651 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.2854962354743173 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.12749999999999995
#    (Other parameter)
#  - prob_meas0_prep1: 0.1104
#    (Other parameter)
#  - prob_meas1_prep0: 0.14459999999999995
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 53 parameters:
#  - T1: 332.06777421298926 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 430.15666112148574 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.621999941877038 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3089157779566661 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0045999999999999375
#    (Other parameter)
#  - prob_meas0_prep1: 0.006399999999999961
#    (Other parameter)
#  - prob_meas1_prep0: 0.0028
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 54 parameters:
#  - T1: 364.55496765364546 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 19.69662247126093 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.501327565347051 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31299719319013514 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.00550000000000006
#    (Other parameter)
#  - prob_meas0_prep1: 0.0076
#    (Other parameter)
#  - prob_meas1_prep0: 0.0033999999999999586
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 55 parameters:
#  - T1: 397.60569323940217 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 44.15325723299107 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.686301071503256 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3100668699291798 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0040000000000000036
#    (Other parameter)
#  - prob_meas0_prep1: 0.0043999999999999595
#    (Other parameter)
#  - prob_meas1_prep0: 0.0036
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 56 parameters:
#  - T1: 312.6107571524634 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 311.6232026440406 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.553675406740916 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.006399999999999961
#    (Other parameter)
#  - prob_meas0_prep1: 0.0096
#    (Other parameter)
#  - prob_meas1_prep0: 0.0031999999999999806
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 57 parameters:
#  - T1: 167.70982358975684 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 28.85913115480959 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.639684938966333 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3110258364070089 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0039000000000000146
#    (Other parameter)
#  - prob_meas0_prep1: 0.006000000000000005
#    (Other parameter)
#  - prob_meas1_prep0: 0.0018
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 58 parameters:
#  - T1: 270.0988464768709 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 39.49873903324939 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.609466315408716 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3120232272887944 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.009199999999999986
#    (Other parameter)
#  - prob_meas0_prep1: 0.0146
#    (Other parameter)
#  - prob_meas1_prep0: 0.0038000000000000256
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 59 parameters:
#  - T1: 323.43576163087033 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 83.05037292141758 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.769981444207988 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3055632788590134 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0017000000000000348
#    (Other parameter)
# ...
#  - readout_error: 0.008199999999999985
#    (Other parameter)
#  - prob_meas0_prep1: 0.0102
#    (Other parameter)
#  - prob_meas1_prep0: 0.006199999999999983
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 105 parameters:
#  - T1: 273.3920959956197 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 90.25253742347816 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.7399070711326505 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.008499999999999952
#    (Other parameter)
#  - prob_meas0_prep1: 0.012
#    (Other parameter)
#  - prob_meas1_prep0: 0.0050000000000000044
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 106 parameters:
#  - T1: 307.2605550540179 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 45.65072248798513 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.710423583854823 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.28699737205284476 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.027800000000000047
#    (Other parameter)
#  - prob_meas0_prep1: 0.0296
#    (Other parameter)
#  - prob_meas1_prep0: 0.026000000000000023
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 107 parameters:
#  - T1: 220.15953876286986 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 41.60373403847856 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.615498693947571 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.30801317939559864 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0022999999999999687
#    (Other parameter)
#  - prob_meas0_prep1: 0.0023999999999999577
#    (Other parameter)
#  - prob_meas1_prep0: 0.0022
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 108 parameters:
#  - T1: 394.42057691205713 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 346.92754510836613 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.54622971482039 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.014000000000000012
#    (Other parameter)
#  - prob_meas0_prep1: 0.010600000000000054
#    (Other parameter)
#  - prob_meas1_prep0: 0.0174
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 109 parameters:
#  - T1: 205.78705226026338 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 13.507714045536114 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.875224159340442 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.30675181805646473 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.05120000000000002
#    (Other parameter)
#  - prob_meas0_prep1: 0.04800000000000004
#    (Other parameter)
#  - prob_meas1_prep0: 0.0544
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 110 parameters:
#  - T1: 246.57979135396778 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 60.83100175573086 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.805824467579053 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3082615805518876 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.005400000000000071
#    (Other parameter)
#  - prob_meas0_prep1: 0.0048000000000000265
#    (Other parameter)
#  - prob_meas1_prep0: 0.006
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 111 parameters:
#  - T1: 178.12782138291868 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 114.55990049332777 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.768731506098183 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.308805156173377 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.006399999999999961
#    (Other parameter)
#  - prob_meas0_prep1: 0.010600000000000054
#    (Other parameter)
#  - prob_meas1_prep0: 0.0022
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 112 parameters:
#  - T1: 371.9534238450372 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 382.7518199963706 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.583645046622054 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: 0 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0049000000000000155
#    (Other parameter)
#  - prob_meas0_prep1: 0.00660000000000005
#    (Other parameter)
#  - prob_meas1_prep0: 0.0032
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 113 parameters:
#  - T1: 268.9157308062332 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 109.40000200254165 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.655646112767932 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3093142958340278 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.007299999999999973
#    (Other parameter)
#  - prob_meas0_prep1: 0.00539999999999996
#    (Other parameter)
#  - prob_meas1_prep0: 0.0092
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 114 parameters:
#  - T1: 202.85995552169663 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 15.909386464325095 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.781723899656403 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.359151679588321 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.011800000000000033
#    (Other parameter)
#  - prob_meas0_prep1: 0.005199999999999982
#    (Other parameter)
#  - prob_meas1_prep0: 0.0184
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 115 parameters:
#  - T1: 301.9970388556499 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 245.7559259241671 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.709538339909825 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3275775129546063 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.01090000000000002
#    (Other parameter)
#  - prob_meas0_prep1: 0.020000000000000018
#    (Other parameter)
#  - prob_meas1_prep0: 0.0018
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 116 parameters:
#  - T1: 61.33525604123158 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 74.40851186270469 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.958861157440809 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3054949382178614 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.007099999999999995
#    (Other parameter)
#  - prob_meas0_prep1: 0.013399999999999967
#    (Other parameter)
#  - prob_meas1_prep0: 0.0008
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 117 parameters:
#  - T1: 230.75158077622115 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 63.38928917448354 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.831597275063236 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.30759466702832383 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.013500000000000068
#    (Other parameter)
#  - prob_meas0_prep1: 0.01639999999999997
#    (Other parameter)
#  - prob_meas1_prep0: 0.0106
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 118 parameters:
#  - T1: 147.31259050924166 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 217.5117737156371 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.749123071456742 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3086757517286422 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0029000000000000137
#    (Other parameter)
#  - prob_meas0_prep1: 0.0056
#    (Other parameter)
#  - prob_meas1_prep0: 0.00019999999999997797
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 119 parameters:
#  - T1: 277.3004112036174 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 253.34574001773348 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.610736677132291 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3114963008800161 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0033000000000000806
#    (Other parameter)
#  - prob_meas0_prep1: 0.005800000000000027
#    (Other parameter)
#  - prob_meas1_prep0: 0.0008
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 120 parameters:
#  - T1: 239.72435755812086 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 417.8839860979219 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.500655812479531 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.31223870265324805 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.01089999999999991
#    (Other parameter)
#  - prob_meas0_prep1: 0.01859999999999995
#    (Other parameter)
#  - prob_meas1_prep0: 0.0032
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 121 parameters:
#  - T1: 323.80586431360655 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 102.22642269886863 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.620340334152359 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.311333521570536 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.044300000000000006
#    (Other parameter)
#  - prob_meas0_prep1: 0.03939999999999999
#    (Other parameter)
#  - prob_meas1_prep0: 0.0492
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 122 parameters:
#  - T1: 107.10179885127899 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 86.71740829793262 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.688046387816731 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3084425173012937 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.005099999999999993
#    (Other parameter)
#  - prob_meas0_prep1: 0.00880000000000003
#    (Other parameter)
#  - prob_meas1_prep0: 0.0014
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 123 parameters:
#  - T1: 252.74340062951453 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 274.93058549505355 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.730565991927177 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.3078326004965146 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.08390000000000009
#    (Other parameter)
#  - prob_meas0_prep1: 0.09740000000000004
#    (Other parameter)
#  - prob_meas1_prep0: 0.0704
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 124 parameters:
#  - T1: 163.3928658915232 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 47.76269670068989 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.635038153210195 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.30850570297447494 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0021999999999999797
#    (Other parameter)
#  - prob_meas0_prep1: 0.0040000000000000036
#    (Other parameter)
#  - prob_meas1_prep0: 0.0004
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 125 parameters:
#  - T1: 240.21883952431128 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 300.4243801908658 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.7371155445247135 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.30715374546988305 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.0048000000000000265
#    (Other parameter)
#  - prob_meas0_prep1: 0.007800000000000029
#    (Other parameter)
#  - prob_meas1_prep0: 0.0018
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Qubit 126 parameters:
#  - T1: 304.3481054142899 us
#    (T1: Relaxation time, defines qubit longevity)
#  - T2: 74.24554738251206 us
#    (T2: Dephasing time, defines qubit coherence)
#  - frequency: 4.702939280693128 GHz
#    (Frequency: Resonance frequency of the qubit, important for addressing and control)
#  - anharmonicity: -0.30311201820062655 GHz
#    (Anharmonicity: Difference in energy levels, impacts gate fidelity and control)
#  - readout_error: 0.006399999999999961
#    (Other parameter)
#  - prob_meas0_prep1: 0.007399999999999962
#    (Other parameter)
#  - prob_meas1_prep0: 0.0054
#    (Other parameter)
#  - readout_length: 1244.4444444444443 ns
#    (Other parameter)
# Bad pipe message: %s [b'\xc4\x04\xa0\xfb\xce\xfb:\x99 \xab\x0c\x96\xf0\x18\xae\x8fMf\x00\x01|\x00\x00\x00\x01\x00\x02\x00\x03\x00\x04\x00\x05\x00\x06\x00\x07\x00\x08\x00\t\x00\n\x00\x0b\x00\x0c\x00\r\x00\x0e\x00\x0f\x00\x10\x00\x11\x00\x12\x00\x13\x00\x14\x00\x15\x00\x16\x00\x17\x00\x18\x00\x19\x00\x1a\x00\x1b']
# Bad pipe message: %s [b'z=\x04U\x18<\xc8\xc3\xfb|\x91\x99\xec#\xf4\xdfq\xa5\x00\x01|\x00\x00\x00\x01\x00\x02\x00\x03\x00\x04\x00\x05\x00\x06\x00\x07\x00\x08\x00\t\x00\n\x00\x0b\x00\x0c\x00\r\x00\x0e\x00\x0f\x00\x10\x00\x11\x00\x12\x00\x13\x00\x14\x00\x15\x00\x16\x00\x17\x00\x18\x00\x19\x00\x1a\x00\x1b\x00/\x000\x001\x002\x003\x004\x005\x006\x007\x008\x009\x00:\x00;\x00<\x00=\x00>\x00?\x00@\x00A\x00B\x00C\x00D\x00E\x00F\x00g\x00h\x00i\x00j\x00k\x00l\x00m', b'', b'\x03', b'\x13\x05\xc0\x01\xc0\x02\xc0\x03\xc0\x04\xc0\x05\xc0\x06\xc0\x07\xc0\x08']

# %% [markdown]
# ## 7. Executing the Circuit and Displaying Results
# Here we execute our circuit both using a simulator and a real NISQ. We run the circuit 4000 times. We know from theory that 50% of the time we should measure the 0 state and 50% of the time we should measure the 1 state. This means in a perfect world we would expect to see 2000 shots being measured in the 0 state and 2000 shots being measured in the 1 state.

# %%
#run the circuit with a sampler (simulator)


from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime.fake_provider import FakeManilaV2
from qiskit_ibm_runtime import SamplerV2 as Sampler
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
sim_ideal = AerSimulator()
result_ideal = sim_ideal.run(qc,shots=4000).result()
plot_histogram(result_ideal.get_counts(0),title="Ran on Quantum Simulator (without noise)")

# %%
fake_manila = FakeManilaV2()
pm = generate_preset_pass_manager(backend=fake_manila, optimization_level=1)
isa_qc = pm.run(qc)
 
# You can use a fixed seed to get fixed results.
options = {"simulator": {"seed_simulator": 42}}

sampler = Sampler(mode=fake_manila, options=options)

results = sampler.run([isa_qc], shots=shots).result()
counts=results[0].data.c.get_counts()


plot_histogram(counts, title ="Ran on Quantum Simulator (with noise)")

# %%
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
backend = service.least_busy(operational=True, simulator=False)
sampler = Sampler(backend)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
qc_circuit = pm.run(qc)
 
# You can use auto-complete to see and complete the options.
sampler.options.default_shots = 4000 

# Get a backend

 
job = sampler.run([qc_circuit])
result = job.result()
# Get results for the first (and only) PUB
pub_result = result[0]

counts= pub_result.data.c.get_counts()
plot_histogram(counts, title ="Ran on Real Quantum Device (noise)")
